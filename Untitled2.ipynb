# %%
import sys
print(sys.prefix)
# !pip3 install pandas
import pandas as pd
import os
from itertools import product
import datetime as dt

import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf

from statsmodels.tsa.stattools import adfuller

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor
from sklearn.metrics import mean_absolute_error


dataset=pd.read_csv("/Users/alishadaredia/Desktop/Ryerson - Arif/CIND820/Price dataset/Metals Futures Historical Data - Sheet1-2.csv")
dataset.describe()
dataset.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10
# Requirement already satisfied: pandas in /Users/alishadaredia/opt/anaconda3/lib/python3.9/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/alishadaredia/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/alishadaredia/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.20.3 in /Users/alishadaredia/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/alishadaredia/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [6], in <module>
#       2 print(sys.prefix)
#       3 get_ipython().system('pip3 install pandas')
# ----> 4 import pandas as pd
#       5 import os
#       6 from itertools import product
#
# ModuleNotFoundError: No module named 'pandas'
